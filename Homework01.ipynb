# %% [markdown]
# #№1 Калькулятор для квадратных уравнений

# %%
a = int(input())
b = int(input())
c = int(input())

print(f'{a}x^2 + {b}x + {c} = 0')
# Out:
# 2
# 4
# 6
# 2x^2 + 4x + 6 = 0

# %% [markdown]
# #№2

# %%
N = int(input())
summ = 0
for i in range(1, N):
  summ += i
print(summ)
# Out:
# 5
# 10

# %% [markdown]
# #№3

# %%
a = int(input())    #подьезд
b = int(input())    #этаж
n = int(input())    #номер
while a == 1 and n <= 20:
  if n == 1 or n == 2 or n == 3 or n == 4:
    print('Подьезд № 1', 'Этаж № 1', 'Квартира №', n)
  elif n == 5 or n == 6 or n == 7 or n == 8:
    print('Подьезд № 1', 'Этаж № 2', 'Квартира №', n)
  elif n == 9 or n == 10 or n == 11 or n == 12:
    print('Подьезд № 1', 'Этаж № 3', 'Квартира №', n)
  elif n == 13 or n == 14 or n == 15 or n == 16:
    print('Подьезд № 1', 'Этаж № 4', 'Квартира №', n)
  else:
    print('Подьезд № 1', 'Этаж № 5', 'Квартира №', n)


    #явно ошибка
